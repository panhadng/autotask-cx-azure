# %%
import requests
import json
import os


def get_all_companies():
    # The base URL where your Flask server is running
    url = "http://localhost:5000/api/companies"

    try:
        # Make GET request to the endpoint
        response = requests.get(url)

        # Raise an exception for bad status codes
        response.raise_for_status()

        # Parse the response
        companies = response.json()

        # Create data directory if it doesn't exist
        os.makedirs('../data', exist_ok=True)

        # Save to a JSON file in the data directory
        file_path = os.path.join('../data', 'companies.json')
        with open(file_path, 'w') as f:
            json.dump(companies, f, indent=2)
        print(f"Companies data saved to {file_path}")

        # Print summary
        print(f"\nSaved {len(companies)} companies to file")

    except requests.exceptions.RequestException as e:
        print(f"Error occurred: {str(e)}")
    except IOError as e:
        print(f"File error occurred: {str(e)}")


if __name__ == "__main__":
    get_all_companies()
# Out:
# Companies data saved to ../data/companies.json
#
# Saved 229 companies to file

# %%
# Read the companies data from the JSON file
try:
    file_path = os.path.join('../data', 'companies.json')
    with open(file_path, 'r') as f:
        companies_data = json.load(f)
    print(f"Successfully loaded {
          len(companies_data)} companies from {file_path}")

    # Print out company names and IDs
    print("\nCompany Details:")
    print("-" * 50)
    for company in companies_data:
        print(f"ID: {company['id']:<8} | Name: {company['companyName']}")
    print("-" * 50)

except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
    companies_data = []
except json.JSONDecodeError:
    print(f"Error: Invalid JSON format in {file_path}")
    companies_data = []
except Exception as e:
    print(f"Error occurred while reading file: {str(e)}")
    companies_data = []
# Out:
# Successfully loaded 229 companies from ../data/companies.json
#
# Company Details:
# --------------------------------------------------
# ID: 0        | Name: FLYONIT
# ID: 174      | Name: Datto Corporation
# ID: 184      | Name: 6's Pizza and Pasta
# ID: 185      | Name: Ace Real Estate
# ID: 186      | Name: AICCI
# ID: 187      | Name: Airmet
# ID: 188      | Name: Akaysha Energy
# ID: 189      | Name: ANGAD Australian Institute of Technology
# ID: 190      | Name: Astracorp
# ID: 191      | Name: Atlas Civil Construction Pty Ltd
# ID: 192      | Name: Australian Friends of Asha
# ID: 193      | Name: Bayside Security Doors and Shower Screens
# ID: 194      | Name: Caliyan Associates
# ID: 195      | Name: Carson Homes
# ID: 196      | Name: Charlie Teo Foundation
# ID: 197      | Name: City Central Apartments
# ID: 198      | Name: Commscode
# ID: 199      | Name: Consulate General of India
# ID: 200      | Name: Covet International
# ID: 201      | Name: Eastside Veterinary Pty Ltd
# ID: 202      | Name: EmbroidMe Melton
# ID: 203      | Name: Engine Pro
# ID: 204      | Name: FCR Motion Technology
# ID: 205      | Name: Fine Cotton Nightwear
# ID: 206      | Name: Glenville Lodge
# ID: 207      | Name: Golden Compass
# ID: 208      | Name: Greenhaven Supported Residential Services
# ID: 209      | Name: Healix Health
# ID: 210      | Name: Hobsons Bay Medical And Skin Center
# ID: 211      | Name: Just Spas Perth
# ID: 212      | Name: Kintax
# ID: 213      | Name: Laverton Medical Centre
# ID: 214      | Name: Laverton Traders Association
# ID: 215      | Name: Loan Market WYNDHAM
# ID: 216      | Name: Majestic Selections
# ID: 217      | Name: Marathon logistics Pty Ltd
# ID: 218      | Name: Marco polo Holiday
# ID: 219      | Name: MC PRO PLASTERING
# ID: 220      | Name: Mechanical Recruitment
# ID: 221      | Name: Migration And Education Experts
# ID: 222      | Name: Moorabool
# ID: 223      | Name: Moreton Group
# ID: 224      | Name: Nav Labs Aus
# ID: 225      | Name: NCS Bookkeeping
# ID: 226      | Name: Need Support Right Now
# ID: 227      | Name: New Age Training
# ID: 228      | Name: Orbit Solutions
# ID: 229      | Name: Pacific Materials Handling
# ID: 230      | Name: Parkdale Motor Inn
# ID: 231      | Name: Prestige Moving
# ID: 232      | Name: Prime Residential Property Management
# ID: 233      | Name: Primus International Education Group Ltd
# ID: 234      | Name: Progressive Health
# ID: 235      | Name: Prohealth Family Medical Centre
# ID: 236      | Name: Rent with Style
# ID: 237      | Name: RK Designs
# ID: 238      | Name: Ruahine Finance
# ID: 239      | Name: Sello Products
# ID: 240      | Name: Shifting Ltd
# ID: 241      | Name: Shiny Building Group
# ID: 243      | Name: Spark Live Pty Ltd
# ID: 244      | Name: Springvale Family medical practice
# ID: 245      | Name: St Vincent de Paul Society
# ID: 246      | Name: Tax Guru
# ID: 247      | Name: Exotic Lily Event Hire
# ID: 248      | Name: The Flooring Emporium
# ID: 249      | Name: Volunteer West
# ID: 250      | Name: Welkin IT
# ID: 251      | Name: Westo Real Estate
# ID: 252      | Name: 1 Gift World
# ID: 253      | Name: A1 Care For You Pty
# ID: 254      | Name: Aarti's Collections Melbourne
# ID: 255      | Name: Accurate Stoneworks
# ID: 256      | Name: Achiever Business Brokers
# ID: 257      | Name: ACP Security Group
# ID: 258      | Name: AEMG Academy Pty Ltd
# ID: 259      | Name: AJS Financial Group
# ID: 260      | Name: AS Wyndham Pty Ltd
# ID: 261      | Name: Asees Migration Australia Pty Ltd
# ID: 262      | Name: Australian Multicultural Community Services
# ID: 263      | Name: Axminster Distributors Pty Ltd
# ID: 264      | Name: B&M Essential Cleaning
# ID: 265      | Name: Bansal Group Pty Ltd
# ID: 266      | Name: Bouquet Production P/L
# ID: 267      | Name: Brick Restoration Services
# ID: 268      | Name: Broadley HR
# ID: 269      | Name: Caliyan Associates
# ID: 270      | Name: Campus Legal
# ID: 272      | Name: Challis & Company
# ID: 274      | Name: CLOSE PTY LTD
# ID: 276      | Name: Complete Lean Solutions Pty Ltd
# ID: 277      | Name: Conquest Equipment
# ID: 278      | Name: Consilium Conveyancing Pty Ltd
# ID: 280      | Name: Courthouse Cafe Australia Pty Ltd
# ID: 282      | Name: Cranbourne Family Medical Centre
# ID: 283      | Name: Dance Vibe
# ID: 284      | Name: Delta 9 Therapeutics
# ID: 285      | Name: Dev Builders Pty Ltd
# ID: 286      | Name: Divine Mercy College
# ID: 287      | Name: Dr Ainee Shafqat
# ID: 288      | Name: Dr Thao Le
# ID: 289      | Name: Dr. Mukesh Haikerwal
# ID: 291      | Name: Eazy Mortage
# ID: 292      | Name: Ellen Patterson
# ID: 293      | Name: Ellsim Carpet Cleaning
# ID: 295      | Name: Empower Your Destiny
# ID: 296      | Name: Eton Farm Education
# ID: 297      | Name: Expert Tax Pty Ltd
# ID: 298      | Name: Falcon Innovations
# ID: 301      | Name: First National Point Cook
# ID: 302      | Name: FMajor Productions PTY LTD
# ID: 303      | Name: Foreo Australia
# ID: 304      | Name: Frontline Property Maintenance
# ID: 305      | Name: Fyber International
# ID: 306      | Name: Fyber Pty Ltd
# ID: 308      | Name: Global Sky Education
# ID: 309      | Name: GMZ Cleaning Services
# ID: 310      | Name: Goldfields Collections Pty Ltd
# ID: 311      | Name: Graduation Rings
# ID: 313      | Name: Greenview Way
# ID: 315      | Name: Health Care 4 You Pty Ltd
# ID: 316      | Name: Healthcare Real Estate
# ID: 317      | Name: Hillscene Family Medical Centre
# ID: 319      | Name: Horse Force Legal
# ID: 320      | Name: HP Automation
# ID: 321      | Name: Ideal Care
# ID: 322      | Name: Inner Care Family Health Clinic
# ID: 323      | Name: Insights to Excellence
# ID: 324      | Name: Intech Institute of technology
# ID: 325      | Name: InTouch ICT Solutions
# ID: 326      | Name: ISMT College Australia
# ID: 327      | Name: Jim's Cleaning Point Cook Central
# ID: 328      | Name: K & B Harrisdale Haulage Pty Ltd
# ID: 329      | Name: KAPS Institute of Management (Primus English)
# ID: 331      | Name: KSK Accounting
# ID: 332      | Name: KW Lending Solutions
# ID: 333      | Name: Lancaster Medical Centre
# ID: 334      | Name: Laura Mundy Dog Training
# ID: 337      | Name: LC Electrical Services Pty Ltd
# ID: 338      | Name: Le Brun & Associates Lawyers
# ID: 339      | Name: Leeway Automation
# ID: 340      | Name: Little Champs Montessori
# ID: 341      | Name: Local Expertz - Caroline Springs
# ID: 345      | Name: Marker Realty
# ID: 347      | Name: MC TOP SHELF PRODUCTS
# ID: 349      | Name: Melton Interfaith Inc
# ID: 351      | Name: Mind Pty Ltd
# ID: 352      | Name: Mission Healthcare
# ID: 353      | Name: Monstera Flowers
# ID: 355      | Name: Motugo Investments Pty Ltd
# ID: 356      | Name: Murnane Print Group
# ID: 357      | Name: My College Ltd
# ID: 358      | Name: My Family Finance
# ID: 359      | Name: My Global Strata Group
# ID: 360      | Name: My Hypnotherapy Sydney
# ID: 364      | Name: Nestech Enterprise P/L
# ID: 366      | Name: Nextlink Pty Ltd
# ID: 367      | Name: OMFB Pacific
# ID: 368      | Name: Opulent Wines
# ID: 370      | Name: Oxygen 2 Clean
# ID: 373      | Name: Phuong Anna Quach
# ID: 374      | Name: Play and Grow
# ID: 375      | Name: PNR Group
# ID: 376      | Name: Point of Difference
# ID: 381      | Name: Prohealth Family Tooradin
# ID: 382      | Name: Red Brick Loans
# ID: 383      | Name: Redstar Real Estate
# ID: 385      | Name: Repower Technologies
# ID: 386      | Name: Riverdale Healthplus
# ID: 389      | Name: S & J Combine Pty Ltd
# ID: 391      | Name: Shahana Moin
# ID: 393      | Name: Shiny Kitchens
# ID: 394      | Name: Sky Solar
# ID: 395      | Name: Smart Loans & Conveyancing
# ID: 396      | Name: Solar Specialist (Fair Value Solar)
# ID: 397      | Name: Solutions 4 Business
# ID: 398      | Name: Southwest Pools & Spas
# ID: 400      | Name: Sports Association of Catholic Co-educational Secondary Schools
# ID: 401      | Name: Springvale Family medical practice
# ID: 402      | Name: SSE Roofing
# ID: 404      | Name: Stressless Life
# ID: 406      | Name: Tecom
# ID: 409      | Name: The Trustee for Prasad Family Trust
# ID: 410      | Name: The Trustee for Ram Kishan & Son's Family Trust
# ID: 411      | Name: The Trustee for Rupela Family Trust
# ID: 412      | Name: The trustee for The Dubash Family Trust ATF Astad Pty Ltd
# ID: 413      | Name: Therapy Animals Australia
# ID: 414      | Name: Trustee For JYOTISHARAD TRUST
# ID: 415      | Name: Uday Nagarkar
# ID: 416      | Name: Uniko Capital
# ID: 417      | Name: United Pop Australia
# ID: 419      | Name: VP Homes PTY LTD
# ID: 420      | Name: Vroom Vroom Recruitment
# ID: 421      | Name: Wautier Carpets
# ID: 422      | Name: way2recruit
# ID: 423      | Name: Weizmann AUSTRALIA
# ID: 426      | Name: Yarra Glen Early Learning Centre
# ID: 427      | Name: Zilch Finance
# ID: 428      | Name: Zoroastrian Association of Victoria
# ID: 429      | Name: Akaysha Energy
# ID: 451      | Name: Akaysha Energy
# ID: 494      | Name: Golden Point Medical Center
# ID: 495      | Name: Kripa Health Pty Ltd
# ID: 496      | Name: Test
# ID: 497      | Name: SUTTON FAMILY LAW
# ID: 498      | Name: MELBA
# ID: 499      | Name: ALFIE
# ID: 500      | Name: Local Expertz Realty-Melton
# ID: 501      | Name: CS Accountants P/L
# ID: 502      | Name: Golden Point Medical Centre
# ID: 503      | Name: Homeo Chakra
# ID: 504      | Name: LE Brun & Associate Lawyer
# ID: 505      | Name: Botanic Apartments
# ID: 506      | Name: Riverdae Health
# ID: 507      | Name: H & P Calibrations Pty Ltd
# ID: 508      | Name: Textking
# ID: 509      | Name: Lead College Pty Ltd
# ID: 510      | Name: Victoria Healthcare pvt ltd
# ID: 511      | Name: JSN Medical
# ID: 512      | Name: Hibob
# ID: 513      | Name: 2Assist
# ID: 514      | Name: Dungog Regional Tourism Inc
# ID: 515      | Name: Bigger Cents
# ID: 516      | Name: Ample Living
# ID: 518      | Name: Truganina Healthplus Pty Ltd
# ID: 519      | Name: Rockms
# ID: 520      | Name: BM Cleaning Group
# ID: 521      | Name: LMK FINANCE
# ID: 522      | Name: Swim 4 All
# --------------------------------------------------

# %%
company_ids = [company['id'] for company in companies_data]
print(company_ids)
# Out:
# [0, 174, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 272, 274, 276, 277, 278, 280, 282, 283, 284, 285, 286, 287, 288, 289, 291, 292, 293, 295, 296, 297, 298, 301, 302, 303, 304, 305, 306, 308, 309, 310, 311, 313, 315, 316, 317, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 331, 332, 333, 334, 337, 338, 339, 340, 341, 345, 347, 349, 351, 352, 353, 355, 356, 357, 358, 359, 360, 364, 366, 367, 368, 370, 373, 374, 375, 376, 381, 382, 383, 385, 386, 389, 391, 393, 394, 395, 396, 397, 398, 400, 401, 402, 404, 406, 409, 410, 411, 412, 413, 414, 415, 416, 417, 419, 420, 421, 422, 423, 426, 427, 428, 429, 451, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 518, 519, 520, 521, 522]

# %%
# Get contacts and domains for all companies
domains_by_company = {}

try:
    for company_id in company_ids:
        try:
            response = requests.get(
                f"http://localhost:5000/api/company/{company_id}/contacts")
            response.raise_for_status()
            contacts = response.json()

            company_domains = set()
            contact_count = 0

            for contact in contacts:
                # Only process up to 2 contacts that have at least one email
                if contact_count >= 2:
                    break

                emails = [
                    contact['emailAddress'],
                    contact['emailAddress2'],
                    contact['emailAddress3']
                ]

                # Check if contact has at least one non-empty email
                valid_emails = [email for email in emails if email]
                if valid_emails:
                    for email in valid_emails:
                        domain = email.split('@')[-1]
                        company_domains.add(domain)
                    contact_count += 1

            domains_by_company[company_id] = list(
                company_domains) if company_domains else None

        except requests.exceptions.RequestException as e:
            print(f"API request error for company {company_id}: {str(e)}")
            domains_by_company[company_id] = None
            continue

    # Save domains to JSON file
    file_path = os.path.join('../data', 'domains.json')
    with open(file_path, 'w') as f:
        json.dump(domains_by_company, f, indent=2)
    print(f"Successfully saved domains for {
          len(domains_by_company)} companies to {file_path}")

except Exception as e:
    print(f"Error occurred: {str(e)}")
# Out:
# Successfully saved domains for 229 companies to ../data/domains.json

# %%
# List of common personal email domains to exclude
personal_domains = {
    'gmail.com',
    'yahoo.com',
    'yahoo.com.au', 
    'hotmail.com',
    'outlook.com',
    'bigpond.com',
    'live.com',
    'icloud.com',
    'mac.com',
    'me.com',
    'msn.com',
    'ymail.com',
    'aol.com',
    "yahoo.co.in"
}

# Load the domains file
file_path = os.path.join('../data', 'domains.json')
with open(file_path, 'r') as f:
    domains_by_company = json.load(f)

# Process each company's domains
for company_id, domains in domains_by_company.items():
    if domains is not None:
        # Filter out personal domains
        business_domains = [d for d in domains if d not in personal_domains]
        # If no business domains remain, set to null
        domains_by_company[company_id] = business_domains if business_domains else None

# Save updated domains back to JSON file
with open(file_path, 'w') as f:
    json.dump(domains_by_company, f, indent=2)

print(f"Successfully removed personal email domains and updated {file_path}")
# Out:
# Successfully removed personal email domains and updated ../data/domains.json
